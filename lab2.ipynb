# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# №1 (3 балла) <br/>
# Напишите программы, которые при помощи matplotlib выводят следующие графики:

# %%
def num_one():

    x = [x*10 for x in range(0, 6)]
    y = [y*30 for y in range(0, 6)]

    plt.plot(x, y, color='blue')
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Draw a line.')

    plt.xlim(0, 50)
    plt.ylim(0, 160)

    plt.show()

def num_two():

    x1 = [10, 20, 30]
    y1 = [20, 40, 10]

    x2 = [10, 20, 30]
    y2 = [40, 10, 30]

    plt.plot(x1, y1, color='blue', linewidth=3, label='line1-width-3')
    plt.plot(x2, y2, color='red', linewidth=5, label='line2-width-5')

    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title(
        'Two or more lines with different widths and colors with suitable legends')
    plt.legend()

    plt.xlim(10, 30)
    plt.ylim(10, 40)

    plt.xticks([10, 15, 20, 25, 30]) # кастыль, но зато как в примере
    
    plt.show()

def num_three():

    x1 = [10, 20, 30]
    y1 = [20, 40, 10]

    x2 = [10, 20, 30]
    y2 = [40, 10, 30]

    plt.plot(x1, y1, color='blue', linewidth=1, linestyle='dotted', label='line1-dotted')
    plt.plot(x2, y2, color='red', linewidth=5, linestyle=':', label='line2-dashed')

    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Plot with two or more lines with different styles')
    plt.legend()

    plt.xlim(10, 30)
    plt.ylim(10, 40)

    plt.xticks([10, 15, 20, 25, 30])

    plt.show()

def num_four():

    x = [1, 4, 5, 6, 7]
    y = [2, 6, 3, 6, 3]

    plt.plot(x, y, linestyle='dashdot', color='red', marker='o', markerfacecolor='blue', markersize=10) # пытался найти нормальный linestyle, но не нашел подходящий как в примере
    
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Display marker')

    plt.xlim(1, 8)
    plt.ylim(1, 8)

    plt.show()

def num_five():

    x1 = [3, 4, 6, 7, 9]
    y1 = [2, 6, 11, 20, 22]

    x2 = [2, 3, 5, 6, 8]
    y2 = [1, 5, 10, 17, 20]

    plt.scatter(x1, y1, color='red', s=50)
    plt.scatter(x2, y2, color='blue', marker='*', s=40)

    plt.xlim(0, 10)
    plt.ylim(0, 30)
    plt.show()

def num_six():
    dates = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
    values = [772.5, 776.4, 776.5, 776.8, 775.1]

    plt.title('Closing stock value of Alphabet Inc.')
    plt.ylabel('Closing Value')
    plt.xlabel('Date')

    plt.plot(dates, values, marker='o', color='red', linewidth=1, markersize=6)

    plt.minorticks_on()
    plt.grid(True, which='major', alpha=0.5, linestyle='-', linewidth=0.8, color='red')
    plt.grid(True, which='minor', alpha=0.2, linestyle='-.', linewidth=0.5, color='gray')

    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)

    plt.ylim(772.5, 777.0)
    plt.xlim('2016-10-03','2016-10-07')

    plt.show()

if __name__ == '__main__':
    num_one()
    num_two()
    num_three()
    num_four()
    num_five()
    num_six()

# %% [markdown]
# №2 (4 балла) <br/>
# Создайте рисунок с основными элементами изображения, похожий на приведенный ниже.
# Элементы изображения обозначены кругами и подписаны синим шрифтом. Допускается
# изменение линий, цвета, толщины линий и т.п., главное, чтобы все обозначенные элементы
# присутствовали.

# %%
np.random.seed(42)
x_scatter = np.random.uniform(0.5, 3.5, 50)
y_scatter = np.random.uniform(0.2, 3.5, 50)
plt.scatter(x_scatter, y_scatter, color='white', s=30, alpha=0.6, marker='o', 
           facecolors='none', edgecolors='black')

x_line = np.linspace(0.5, 3.8, 100)
y_line = 3 * np.exp(-2 * (x_line - 1)) + 2
plt.plot(x_line, y_line, 'b-', linewidth=2, label='Синяя линия')

x_spline = np.linspace(0.5, 3.5, 100)
y_spline = 0.5 + 0.3 * np.sin(2 * (x_spline - 1)) + 0.2 * (x_spline - 1)
plt.plot(x_spline, y_spline, 'r-', linewidth=2, label='Красная линия')

plt.xlabel('Подпись оси OX')
plt.ylabel('Подпись оси OY')

plt.gca().yaxis.set_major_locator(plt.MultipleLocator(1.0))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.25))

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1.0))
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.25))
plt.gca().xaxis.set_minor_formatter(plt.FormatStrFormatter('%.2f'))

plt.grid(True, which='major', linestyle='-', alpha=0.7)
plt.grid(True, which='minor', linestyle='--', alpha=0.4)

plt.title('Элементы изображения')
plt.legend()

plt.xlim(0, 4)
plt.ylim(0, 4)

plt.show()

# %% [markdown]
# №3 (2 балла) <br/>
# Постройте график функции <br/>
# ![image.png](attachment:image.png) <br/>
# и по графику найдите корни уравнения y(x) = 0. <br/>
# (Не нужно применять численных методов — просто так подберите отображение, чтобы на графике были видны корни функции.)

# %%
x = np.linspace(-3, 4, 1000)
y = x**2 - x - 6

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(x, y, label="y(x) = x^2 - x - 6", color="blue", linewidth=2)

ax.axhline(0, color='gray', linestyle='--', linewidth=1)

roots = [-2, 3]
ax.scatter(roots, [0, 0], color='red', zorder=5, label='Roots $y=0$')

ax.set_title("y(x) = x^2 - x - 6")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# №4 (2 балла) <br/>
# Постройте график функции <br/>
# ![image.png](attachment:image.png)

# %%
def calc(t):
    a = 1 + np.tan(1 / (1 + np.sin(t)**2))
    b = (t**2 + 1) * np.exp(-np.abs(t) / 10)
    res = np.log(b) / np.log(a)
    res[(a <= 0) | (a == 1)] = np.nan
    return res

t = np.linspace(-10, 10, 1000)
plt.plot(t, calc(t), 'blue', linewidth=2)
plt.grid(True)
plt.ylim(-2, 11)
plt.xlim(-11, 11)
plt.show()

# %% [markdown]
# №5 (4 балла) <br/>
# Напишите программы, которые при помощи matplotlib выводят следующие диаграммы:

# %%
def num_one():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.5, 8.8, 8, 7.7, 6.7]
    x_pos = [2, 7, 12, 17, 22, 27]

    plt.bar(x_pos, popularity, color='blue', width=4)
    plt.xlabel("Languages")
    plt.ylabel("Popularity")
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")

    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))

    plt.xticks(np.linspace(0, 25, 6), lang)

    plt.xlim(0, 30)
    plt.ylim(0, 25)

    plt.show()

def num_two():
    lang = ['Java', 'Python', 'PHP', 'JS', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [2, 7, 12, 17, 22, 27]

    plt.barh(x_pos, popularity, color="green", height=4)
    plt.xlabel("Popularity")
    plt.ylabel("Languages")
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")

    plt.minorticks_on()

    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    
    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))

    plt.yticks(np.linspace(0, 25, 6), lang)

    plt.xlim(0, 25)
    plt.ylim(0, 30)

    plt.show()

def num_three():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [2, 7, 12, 17, 22, 27]
    colors = ['red', 'black', 'green', 'blue', 'yellow', 'cyan']

    plt.bar(x_pos, popularity, color=colors, width=4)

    plt.xlabel("Languages")
    plt.ylabel("Popularity")
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")

    plt.minorticks_on()

    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)

    plt.gca().set_xticks(np.arange(0, 31, 5))

    plt.xticks(np.linspace(0, 25, 6), lang)

    plt.xlim(0, 30)
    plt.ylim(0, 25)

    plt.show()

def num_four():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [2, 7, 12, 17, 22, 27]

    bars = plt.bar(x_pos, popularity, color="blue", width=4) 
    plt.xlabel("Languages")
    plt.ylabel("Popularity")
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")

    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    
    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))

    plt.xticks(np.linspace(0, 25, 6), lang)

    plt.xlim(0, 30)
    plt.ylim(0, 25)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.6f}', ha='center', va='bottom', fontsize=10)

    plt.show()

def num_five():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [0.25, 5.5, 11, 17.25, 20.5, 25.75]
    widths = [0.5, 1, 2, 4.5, 1, 1.5]

    plt.bar(x_pos, popularity, color='blue', width=widths)

    plt.xlabel("Languages")
    plt.ylabel("Popularity")
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")

    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    plt.gca().tick_params(which='major', length=0)
    plt.gca().tick_params(which='minor', length=0)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))

    plt.xticks(np.linspace(0, 25, 6), lang)

    plt.xlim(0, 30)
    plt.ylim(0, 25)

    plt.show()

def num_six():
    persons = ['G1', 'G2', 'G3', 'G4', 'G5']
    men_scores = [22, 30, 33, 30, 26]
    women_scores = [25, 32, 30, 35, 29]

    x_positions = np.array([1.5, 6.5, 11.5, 16.5, 21.5])
    bar_width = 1.5

    plt.bar(x_positions - bar_width/2, men_scores, color='green', edgecolor='black', linewidth=1, width=bar_width, label='Men')

    plt.bar(x_positions + bar_width/2, women_scores, color='red', edgecolor='black', linewidth=1, width=bar_width, label='Women')

    plt.xlabel('Person')
    plt.ylabel('Scores')
    plt.title('Scores by person')


    plt.gca().tick_params(axis='y', direction='in', which='both', 
                   left=True, right=True, labelleft=True, labelright=False)

    plt.gca().tick_params(axis='x', direction='in', which='major',
                   bottom=False, top=True, labelbottom=True, labeltop=False)
    
    plt.xticks(x_positions, persons)

    plt.xlim(0, 25)
    plt.ylim(0, 35)

    plt.legend()

    plt.show()

def num_seven():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]

    explode = (0.1, 0, 0, 0, 0, 0)
    contour = {'edgecolor': 'black'}

    plt.pie(
        popuratity, 
        explode=explode, 
        labels=lang, 
        colors=colors,
        autopct='%1.1f%%',
        shadow=True, 
        startangle=140,
        wedgeprops=contour)

    plt.show()

def num_eight():
    lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]

    explode = (0.1, 0, 0, 0, 0, 0.1)
    contour = {'edgecolor': 'black'}

    plt.pie(
        popuratity, 
        explode=explode, 
        labels=lang, 
        colors=colors,
        autopct='%1.1f%%',
        shadow=True, 
        startangle=140,
        wedgeprops=contour)
    
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", bbox={'facecolor':'0.8'})

    plt.show()

if __name__ == '__main__':
    num_one()
    num_two()
    num_three()
    num_four()
    num_five()
    num_six()
    num_seven()
    num_eight()

# %% [markdown]
# №6 (3 балла) <br/>
# Напишите программы, которые при помощи matplotlib выводят следующие рисунки:

# %%
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from sklearn.datasets import load_iris

iris = load_iris()
# petal_length - это 3-й столбец (индекс 2) в массиве данных iris
x_data = iris.data[:, 2]

plt.figure(figsize=(8, 5))

plt.hist(x_data, bins=7, density=True, color='pink', alpha=0.7, label='Histogram')

density = gaussian_kde(x_data)
xs = np.linspace(x_data.min() - 1, x_data.max() + 1, 200)
plt.plot(xs, density(xs), color='palevioletred', linewidth=2, label='KDE')

plt.xlabel("petal_length")
plt.show()

# %%
x = np.linspace(0, 100, 100)
y = 2 * x

fig = plt.figure(figsize=(7, 5))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 

ax1.plot(x, y, 'b')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2 = fig.add_axes([0.55, 0.5, 0.25, 0.25]) 

ax2.plot(x, y, 'b')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

ax2.set_xlim(0, 100)
ax2.set_ylim(0, 200)

plt.show()

# %%
x = np.linspace(0, 100, 100)
y = 2 * x
z = x ** 2

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 3))

axes[0].plot(x, y, color="blue", linewidth=5, linestyle="-")
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")

axes[1].plot(x, z, color="red", linewidth=3, linestyle="--")
axes[1].set_xlabel("x")
axes[1].set_ylabel("z")

plt.tight_layout()
plt.show()
