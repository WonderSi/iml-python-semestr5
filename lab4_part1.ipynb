# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

# %% [markdown]
# Просмотрите типы доступных в Seaborn наборов данных, скопируйте их и вставьте в результат примера 1.

# %%
def example1():
    dataset_names = sb.get_dataset_names()
    for i in range(0, len(dataset_names), 3):
        group = dataset_names[i:i+3]
        print(", ".join(group))  
          
example1()
# Out:
# anagrams, anscombe, attention
# brain_networks, car_crashes, diamonds
# dots, dowjones, exercise
# flights, fmri, geyser
# glue, healthexp, iris
# mpg, penguins, planets
# seaice, taxis, tips
# titanic

# %% [markdown]
# Вставьте результат импорта данных. Перечислите параметры данных 'iris'.

# %%
def example2a():
    df = sb.load_dataset('iris')
    print(df.head())

example2a()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Вставьте результат импорта данных. Перечислите параметры данных 'tips'.

# %%
def example2b():
    df = sb.load_dataset('iris')
    print(pd.DataFrame({
    'Столбец': df.columns,
    'Тип_данных': [str(dtype) for dtype in df.dtypes]
}).to_string(index=False))
        
example2b()
# Out:
#      Столбец Тип_данных
# sepal_length    float64
#  sepal_width    float64
# petal_length    float64
#  petal_width    float64
#      species     object

# %% [markdown]
# Постройте изображение с настройками по умолчанию в `Matplotlib`:
# ```
# def sinplot(flip = 1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
# sinplot()
# plt.show()
# ```

# %%
def example3():
    def sinplot(flip = 1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
    sinplot()
    plt.show()

example3()

# %% [markdown]
# Измените тот же график на значения по умолчанию в Seaborn, используя функцию set():
# ```
# def sinplot(flip = 1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
# sb.set()
# sinplot()
# plt.show()
# ```

# %%
def example4():
    def sinplot(flip = 1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
            
    sb.set()
    sinplot()
    plt.show()

example4()

# %% [markdown]
# Применим стиль `"whitegrid"`
# ```
# def sinplot(flip=1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
# sb.set_style("whitegrid")
# sinplot()
# plt.show()
# ```

# %%
def example5():
    def sinplot(flip=1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
    sb.set_style("whitegrid")
    sinplot()
    plt.show()

example5()

# %% [markdown]
# ```
# def sinplot(flip=1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
# sb.set_style("white")
# sinplot()
# sb.despine()
# plt.show()
# ```

# %%
def example6():
    def sinplot(flip=1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i*.5)*(7 - i)*flip)
    sb.set_style("white")
    sinplot()
    sb.despine()
    plt.show()

example6()

# %% [markdown]
# Выполните инструкцию:
# `sb.axes_style()`
# Приведите список параметров функции style.

# %%
def example7():
    sb_styles = sb.axes_style()
    for key, value in sb_styles.items():
        print(f"{key}: {value}")

example7()
# Out:
# axes.facecolor: white
# axes.edgecolor: .15
# axes.grid: False
# axes.axisbelow: True
# axes.labelcolor: .15
# figure.facecolor: white
# grid.color: .8
# grid.linestyle: -
# text.color: .15
# xtick.color: .15
# ytick.color: .15
# xtick.direction: out
# ytick.direction: out
# lines.solid_capstyle: CapStyle.round
# patch.edgecolor: w
# patch.force_edgecolor: True
# image.cmap: rocket
# font.family: ['sans-serif']
# font.sans-serif: ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif']
# xtick.bottom: False
# xtick.top: False
# ytick.left: False
# ytick.right: False
# axes.spines.left: True
# axes.spines.bottom: True
# axes.spines.right: True
# axes.spines.top: True

# %% [markdown]
# ```
# def sinplot(flip=1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
#
# sb.set_style("darkgrid", {'axes.axisbelow': False}) # Изменили здесь
# sinplot()
# sb.despine()
# plt.show()
# ```

# %%
def example8():
    def sinplot(flip=1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
    sb.set_style("darkgrid", {'axes.axisbelow': False})
    sinplot()
    sb.despine()
    plt.show()


example8()

# %% [markdown]
# ```
# def sinplot(flip=1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
#
# sb.set_style("darkgrid", {'axes.axisbelow': True}) # Изменили здесь
# sinplot()
# sb.despine()
# plt.show()
# ```
# Уточнение: `'axes.axisbelow'` может принимать два
# значения: `False` и `True`.

# %%
def example9():
    def sinplot(flip=1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
    sb.set_style("darkgrid", {'axes.axisbelow': True})
    sinplot()
    sb.despine()
    plt.show()


example9()

# %% [markdown]
# ```
# current_palette = sb.color_palette()
# sb.palplot(current_palette)
# plt.show()
# ```

# %%
def example10():
    current_palette = sb.color_palette()
    sb.palplot(current_palette)
    plt.show()

example10()

# %% [markdown]
# 10

# %% [markdown]
# а) Выведите рисунок последовательной палитры.
# ```
# current_palette = sb.color_palette()
# sb.palplot(sb.color_palette("Greens"))
# plt.show()
# ```
# б) Выберите другой цвет и приведите изображение последовательной палитры.

# %%
def example11a():
    current_palette = sb.color_palette()
    sb.palplot(sb.color_palette("Greens"))
    plt.show()

def example11b():
    current_palette = sb.color_palette()
    sb.palplot(sb.color_palette("Reds"))
    plt.show()

example11a()
example11b()

# %% [markdown]
# а) Выведите рисунок расходящейся палитры.
# ```
# current_palette = sb.color_palette()
# sb.palplot(sb.color_palette("BrBG", 7))
# plt.show()
# ```
# б) Приведите рисунок расходящейся палитры с другим сочетанием
# цветов.

# %%
def example12a():
    current_palette = sb.color_palette()
    sb.palplot(sb.color_palette("BrBG", 7))
    plt.show()

def example12b():
    current_palette = sb.color_palette()
    sb.palplot(sb.color_palette("RdBu", 7))
    plt.show()

example12a()
example12b()

# %% [markdown]
# ```
# def sinplot(flip = 1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1, 5):
#         plt.plot(x, np.sin(x + i * .5) * (7 - i)*flip)
#
# sb.set_style("white")
# sb.set_palette("husl")
# sinplot()
# plt.show()
# ```

# %%
def example13():
    def sinplot(flip = 1):
        x = np.linspace(0, 14, 100)
        for i in range(1, 5):
            plt.plot(x, np.sin(x + i * .5) * (7 - i)*flip)
    sb.set_style("white")
    sb.set_palette("husl")
    sinplot()
    plt.show()

example13()

# %% [markdown]
# ```
# sb.set()
# # Набор данных 'чаевые'
# tips = sb.load_dataset('tips')
# ax = sb.scatterplot(x = 'total_bill', y='tip', data = tips)
# plt.show()
# ```

# %%
def example14():
    sb.set()
    tips = sb.load_dataset('tips')
    ax = sb.scatterplot(x = 'total_bill', y='tip', data = tips)
    plt.show()

example14()

# %% [markdown]
# Есть ли зависимость между параметрами tip и total_bill? Как Вы ее можете охарактеризовать?
#
# Зависимость: чем больше общий чек (total bill), тем меньше вероятность получить чаевые.
#
# И наоборот: чем меньше общий чек, тем больше шансов получить чаевые.

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.distplot(df['petal_length'],kde = False)
# plt.show()
# ```

# %%
def example15():
    df = sb.load_dataset('iris')
    sb.displot(df['petal_length'],kde = False)
    plt.show()

example15()

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.distplot(df['petal_length'], hist=False)
# plt.show()
# ```

# %%
def example16():
    df = sb.load_dataset('iris')
    sb.distplot(df['petal_length'], hist=False)
    plt.show()


example16()
# Out:
# C:\Users\011ko\AppData\Local\Temp\ipykernel_32716\565440906.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['petal_length'], hist=False)

# %% [markdown]
# а) Прокомментируйте программный код и полученный рисунок.
# ```
# df = sb.load_dataset('iris')
# sb.distplot(df['petal_length'])
# plt.show()
# ```
# б) Сравните два рисунка а) и б).
# ```
# df = sb.load_dataset('iris')
# sb.distplot(df['petal_length'], hist_kws = {"alpha": 1})
# plt.show()
# ````

# %%
def example17a():
    df = sb.load_dataset('iris')
    sb.displot(df['petal_length'])
    plt.show()

example17a()

# %%
def example17b():
    df = sb.load_dataset('iris')
    sb.distplot(df['petal_length'], hist_kws = {"alpha": 1})
    plt.show()


example17b()
# Out:
# C:\Users\011ko\AppData\Local\Temp\ipykernel_32716\700700941.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['petal_length'], hist_kws = {"alpha": 1})

# %% [markdown]
# а) Прокомментируйте программный код и полученный рисунок: Строим график с параметрами по умолчанию. б) Сравните рисунки: Они идентичны за исключением того, что под б) график менее прозрачный
# ```
# df = sb.load_dataset('iris')
# sb.jointplot(x = 'petal_length', y = 'petal_width', data = df)
# plt.show()
# ```

# %%
def example18():
    df = sb.load_dataset('iris')
    sb.jointplot(x = 'petal_length', y = 'petal_width', data = df)
    plt.show()

example18()

# %% [markdown]
# Между какими перемеными взаимосвязь и какая?
#
# Рассматривается взаимосвязь между длиной и шириной лепестков<br/>
# Прямая зависимость

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.set_style("ticks")
# sb.pairplot(df, hue = 'species', diag_kind = "kde", kind = "scat
# ter", palette = "husl")
# plt.show()
# ```

# %%
def example19():
    df = sb.load_dataset('iris')
    sb.set_style("ticks")
    sb.pairplot(df, hue = 'species', diag_kind = "kde", kind = "scatter", palette = "husl")
    plt.show()

example19()

# %% [markdown]
# ```
# iris = sb.load_dataset("iris")
# ax = sb.pairplot(iris)
# plt.show()
# ```

# %%
def example20():
    iris = sb.load_dataset("iris")
    ax = sb.pairplot(iris)
    plt.show()

example20()

# %% [markdown]
# Опишите различие в изображениях рисунка 19 и 20.
#
# В 19м у нас KDE с заливкой по диагонали и разные цвета для scatter графиков. По цвету идёт различие в видах цветов.<br/>
# в 20м у всего одинаковые цвета и вместо KDE по диагонали используется гистограмма, также одного цвета.

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.stripplot(x = "species", y = "petal_length", data = df, jitte
# r = False)
# plt.show()
# ```

# %%
def example21():
    df = sb.load_dataset('iris')
    sb.stripplot(x = "species", y = "petal_length", data = df, jitter = False)
    plt.show()

example21()

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.stripplot(x = "species", y = "petal_length", data = df, jitte
# r = True)
# plt.show()
# ```

# %%
def example22():
    df = sb.load_dataset('iris')
    sb.stripplot(x = "species", y = "petal_length", data = df, jitter = True)
    plt.show()

example22()

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb.swarmplot(x = "species", y = "petal_length", data = df)
# plt.show()
# ```

# %%
def example23():
    df = sb.load_dataset('iris')
    sb.swarmplot(x = "species", y = "petal_length", data = df)
    plt.show()

example23()
# Out:
# c:\Users\011ko\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ```
# df = sb.load_dataset('iris')
# sb. barplot(x = "species", y = "petal_length", data = df)
# plt.show()
# ```

# %%
def example24():
    df = sb.load_dataset('iris')
    sb. barplot(x = "species", y = "petal_length", data = df)
    plt.show()

example24()

# %% [markdown]
# а) По тем же данным постройте коробчатую диаграмму
# ```
# df = sb.load_dataset('iris')
# sb. boxplot(x = "species", y = "petal_length", data = df)
# plt.show()
# ```
# **Укажите примерно величины медиан для каждого типа ириса и концы доверительных интервалов для параметра "petal_length".**
#
# б) Постройте boxplot с другим расположением коробок
# ```
# df = sb.load_dataset('iris')
# sb.boxplot(data = df, orient = "h")
# plt.show()
# ```

# %%
def example25a():
    df = sb.load_dataset('iris')
    sb. boxplot(x = "species", y = "petal_length", data = df)
    plt.show()

example25a()

# %% [markdown]
# Укажите примерно величины медиан для каждого типа ириса и концы доверительных интервалов для параметра "petal_length".
#
# Setosa
#
# Медиана ≈ 1.5<br/>
# Нижний конец ≈ 1.4<br/>
# Верхний конец ≈ 1.6<br/>
#
# Versicolor
#
# Медиана ≈ 4.3<br/>
# Нижний конец ≈ 4.0<br/>
# Верхний конец ≈ 4.7<br/>
#
# Virginica
#
# Медиана ≈ 5.5<br/>
# Нижний конец ≈ 5.0<br/>
# Верхний конец ≈ 6.0

# %%
def example25b():
    df = sb.load_dataset('iris')
    sb.boxplot(data = df, orient = "h")
    plt.show()

example25b()

# %% [markdown]
# ```
# df = sb.load_dataset('tips')
# sb.violinplot(x = "day", y = "total_bill", data=df)
# plt.show()
# ```

# %%
def example26():
    df = sb.load_dataset('tips')
    sb.violinplot(x = "day", y = "total_bill", data=df)
    plt.show()

example26()

# %% [markdown]
# ```
# df = sb.load_dataset('tips')
# sb.violinplot(x = "day", y = "total_bill", hue = 'sex', data = df)
# plt.show()
# ```

# %%
def example27():
    df = sb.load_dataset('tips')
    sb.violinplot(x = "day", y = "total_bill", hue = 'sex', data = df)
    plt.show()

example27()

# %% [markdown]
# Отличие в посещении ресторана мужчинами и женщинами:
#
# Чек мужчин в ресторане явно больше, чем женщин независимо от дня недели.<br/>
# Женщины чаще имеют меньшие показатели счета, а распределение у них более равномерное

# %% [markdown]
# Построим гистограмму среднего числа выживших мужчин и женщин в каждом классе кают.
# ```
# df = sb.load_dataset('titanic')
# sb.barplot(x = "sex", y = "survived", hue = "class", data = df)
# plt.show()
# ```

# %%
def example28():
    df = sb.load_dataset('titanic')
    sb.barplot(x = "sex", y = "survived", hue = "class", data = df)
    plt.show()

example28()

# %% [markdown]
# 1) сравните число выживших женщин и мужчин;<br/>
# Женщин выжило сильно больше
#
# 2) сравните число выживших по классам кают.<br/>
# Больше всего выжило тех, кто имел каюту первого класса<br/>
# Меньше всего выжило тех, кто имел каюту 3го класса<br/>
# Т.е. чем выше класс каюты = тем выше шанс выжить.

# %% [markdown]
# ```
# df = sb.load_dataset('titanic')
# sb.countplot(x = "class", data = df, palette = "Blues")
# plt.show()
# ```

# %%
def example29():
    df = sb.load_dataset('titanic')
    sb.countplot(x = "class", data = df, palette = "Blues")
    plt.show()

example29()
# Out:
# C:\Users\011ko\AppData\Local\Temp\ipykernel_32716\918990366.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x = "class", data = df, palette = "Blues")

# %% [markdown]
# Больше всего пассажиров было в 3м классе <br/>
# Меньше всего — во втором классе <br/>
# Кол-во пассажиров первого класса было чуть выше 200 <br/>

# %% [markdown]
# ```
# df = sb.load_dataset('titanic')
# sb.pointplot(x = "sex", y = "survived", hue = "class", data = df)
# plt.show()
# ```

# %%
def example30():
    df = sb.load_dataset('titanic')
    sb.pointplot(x = "sex", y = "survived", hue = "class", data = df
    )
    plt.show()

example30()

# %% [markdown]
# Информация, конечно же, совпадает. Читаемость графика из 28го примера лучше.

# %% [markdown]
# Построим regplot и затем lmplot по одним и тем же данным.
# ```
# df = sb.load_dataset('tips')
# sb.regplot(x = "total_bill", y = "tip", data = df)
# sb.lmplot(x = "total_bill", y = "tip", data = df)
# plt.show()
# ```

# %%
def example31():
    df = sb.load_dataset('tips')
    sb.regplot(x = "total_bill", y = "tip", data = df)
    sb.lmplot(x = "total_bill", y = "tip", data = df)
    plt.show()

example31()

# %% [markdown]
# Сравните рисунки и укажите разницу в изображениях. <br/>
# lmplot с чуть более квадратными пропорциями

# %% [markdown]
# Построим линейную регрессию, когда одна из переменных принимает дискретные значения.
# ```
# df = sb.load_dataset('tips')
# sb.lmplot(x = "size", y = "tip", data = df)
# plt.show()
# ```

# %%
def example32():
    df = sb.load_dataset('tips')
    sb.lmplot(x = "size", y = "tip", data = df)
    plt.show()

example32()

# %% [markdown]
# Линия регрессии отображает положительную связь между размером и сумой чаевых с доверительным интервалом, кт. расширяется при бОльших размерах.

# %% [markdown]
# ```
# df = sb.load_dataset('anscombe')
# sb.lmplot(x="x", y="y", data=df.query("dataset == 'I'"))
# plt.show()
# ```

# %%
def example33():
    df = sb.load_dataset('anscombe')
    sb.lmplot(x="x", y="y", data=df.query("dataset == 'I'"))
    plt.show()

example33()

# %% [markdown]
# По вашему мнению, данные хорошо подходят для модели линейной регрессии? НЕТ

# %% [markdown]
# ```
# df = sb.load_dataset('anscombe')
# sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
# plt.show()
# ```

# %%
def example34():
    df = sb.load_dataset('anscombe')
    sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
    plt.show()

example34()

# %% [markdown]
# а) хорошо ли ложатся точки на линию регрессии? <br/>
# -да, хорошо, большинство точек расположено относительно близко к прямой
#
# б) большое ли отклонение точек данных от линии регрессии? <br/>
# -нет, не большое
#
# в) какой функцией, по вашему мнению, может быть описана регрессионная модель? <br/>
# y = kx + b
